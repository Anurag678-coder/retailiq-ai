# %% [markdown]
# # 03 — Forecasting Models
# Trains and compares Linear Regression, Random Forest, XGBoost, and Prophet. See `src/forecasting.py`.

# %%
import sys
sys.path.append('..')
from src.forecasting import run_all_models

comparison_df, trained_models = run_all_models()

# %% [markdown]
# ## Model comparison table

# %%
comparison_df

# %% [markdown]
# ## Visualize R2 by model

# %%
import matplotlib.pyplot as plt
comparison_df.set_index('model')['R2'].plot(kind='bar', title='R2 by Model')
plt.axhline(0, color='gray', linewidth=0.8)
plt.show()
