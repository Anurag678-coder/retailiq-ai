# %% [markdown]
# # 04 — SHAP Explainability
# Explains the tree-based model's predictions. Run `03_forecasting_models.ipynb` first so `models/all_models.pkl` exists.

# %%
import sys
sys.path.append('..')
from src.explainability import run_shap_analysis

importance_df = run_shap_analysis()
importance_df

# %% [markdown]
# ## View saved plots

# %%
from IPython.display import Image
Image('../models/shap_summary.png')

# %%
from IPython.display import Image
Image('../models/shap_waterfall.png')
